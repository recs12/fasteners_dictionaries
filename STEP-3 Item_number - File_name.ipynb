# %%
from inventories.inventory import INVENTORY_SCREWS, INVENTORY_NUTS, INVENTORY_WASHERS
from inventories.convertor import itemnumber_equivalences

# %%
inventory = {**INVENTORY_SCREWS, **INVENTORY_NUTS, **INVENTORY_WASHERS}

# %%
inventory = {j:i for i,j in inventory.items()} #reverse keys and values;

# %%
# jde dict to cad dict:
#e.g {185671:185680,  24107929:185536}
def jde2cad(dict_to_convert):
    return {total_reverse_inv.get(str(j), str(j)): inventory.get(str(k), str(k)) for j,k in dict_to_convert.items()}

# %%
#insert the list of notfoundTeamcenter 
# import file with list

# %%
#sorted dict:
itemnumber_equivalences = {k:v for k,v in sorted(itemnumber_equivalences.items(), key=lambda item: item[0])} #if k not in notfoundlist  if v not in notfound list

# %%
itemnumber_equivalences
# Out:
# {'107190': '185572',
#  '107191': '185790',
#  '107200': '118588',
#  '107559': '185748',
#  '107574': '185792',
#  '107576': '24104823',
#  '107691': '118418',
#  '108007': '185738',
#  '108726': '123481',
#  '116850': '181731',
#  '117463': '24104866',
#  '117464': '185619',
#  '117533': '185779',
#  '117586': '118121',
#  '117588': '24104862',
#  '117589': '118846',
#  '117590': '185701',
#  '117591': '118590',
#  '117592': '118589',
#  '117609': '185560',
#  '117613': '24106028',
#  '117614': '24104712',
#  '117615': '185639',
#  '117616': '185777',
#  '117617': '118477',
#  '117620': '24104865',
#  '117621': '118570',
#  '117622': '118296',
#  '117623': '24104892',
#  '117624': '24104792',
#  '117625': '185794',
#  '117626': '117113',
#  '117627': '118178',
#  '117628': '117619',
#  '117629': '185742',
#  '117630': '24104771',
#  '117631': '118418',
#  '117632': '24104869',
#  '117633': '24104772',
#  '117634': '24104895',
#  '117651': '118476',
#  '117652': '172606',
# ...

# %%
itemnumber_equivalences = jde2cad(itemnumber_equivalences)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-9967de969a8c> in <module>
# ----> 1 itemnumber_equivalences = jde2cad(itemnumber_equivalences)
#
# <ipython-input-13-ec6bb071087a> in jde2cad(dict_to_convert)
#       2 #e.g {185671:185680,  24107929:185536}
#       3 def jde2cad(dict_to_convert):
# ----> 4     return {total_reverse_inv.get(str(j), str(j)): inventory.get(str(k), str(k)) for j,k in dict_to_convert.items()}
#
# <ipython-input-13-ec6bb071087a> in <dictcomp>(.0)
#       2 #e.g {185671:185680,  24107929:185536}
#       3 def jde2cad(dict_to_convert):
# ----> 4     return {total_reverse_inv.get(str(j), str(j)): inventory.get(str(k), str(k)) for j,k in dict_to_convert.items()}
#
# NameError: name 'total_reverse_inv' is not defined

# %%
itemnumber_equivalences = {k:v for k,v in sorted(itemnumber_equivalences.items(), key=lambda item: item[0])}

# %%
itemnumber_equivalences
