# %%
import pandas as pd

# %%
screws = pd.read_excel('screws.xlsx')

# %%
screws = screws[['Filename','Document Number']]

# %%
screws = screws.set_index('Filename')

# %%
screws = screws.to_dict('dict')['Document Number']

# %%
screws
# Out:
# {'VTCY_0.138-32X0.625_SS.PAR': '185671',
#  'VTCY_0.250-20X1.750_SS.PAR': '185680',
#  'VTFR_0.625-11X3.000.PAR': '24107929',
#  'VTHE_0.313-18X2.500_SS.PAR': '185536',
#  'VTHE_0.375-16X2.750_GR8.PAR': '163879',
#  'VTHE_0.625-11X4.000_GR5_FULL _THD.PAR': '204569',
#  'VTRO_0.250-20X1.000_SS.PAR': '146368',
#  'VTRO_0.250-20X1.500_GR5.PAR': '162413',
#  'VP_0.313-18X0.625_SS316.PAR': '011',
#  'VTCYE_0.625-11X0.750X2.500.PAR': '131313131',
#  'VTCYE_0.625-11X0.750X4.000.PAR': '8888888888',
#  'VTCYE_0.625-11X0.750X4.500.PAR': '23232221',
#  'VTFR_0.190-24X0.500_SS316.PAR': '000003',
#  'VTFR_M10-1.50X040_SS316.PAR': '00002',
#  'VTHE_0.250-20X2.500_SS316.PAR': '09090',
#  'VTHE_0.250-20X2.750_SS316.PAR': '07',
#  'VTHE_0.375-16X1.000_SS316.PAR': '0005',
#  'VTHE_0.875-9X9.500_GR5.PAR': '165582',
#  'VTHE_0.875-9X9.500_GR8.PAR': '165597',
#  'VTHE_1.250-7X6.000_GR5.PAR': '165560',
#  'VTHE_1.250-7X9.500_GR5..par': '136700',
#  'VTRO_0.190-24X0.375_SS.par': 'XXXXXX',
# ...

# %% [markdown]
# Index(['Path ', 'Filename', 'New path', 'New Filename ', 'Delete',
#        'Document Number', 'Revision', 'Project Name', 'Teamcenter Item Type',
#        'PartType', 'TC_ImportTime', 'Last Saved Version', 'JDELITM',
#        'JDEDSC1_F', 'JDEDSC1_A', 'JDEDSC2_F', 'JDEDSC2_A', 'JDESTRX_F',
#        'JDESTRX_A', 'DSC_F', 'DSC_A', 'EQUIP_F', 'EQUIP_A', 'SERIE_F',
#        'SERIE_A', 'MODULE_F', 'MODULE_A', 'DIM1', 'DIM2', 'CAD_UOM',
#        'PartContainsParameters', 'PartMayContainSpare', 'CommentForSpare',
#        'EstimatedCost', 'JDEPRP1Code', 'JDEPRP2Code', 'JDEPRP3Code', 'JDEPRP1',
#        'JDEPRP2', 'JDEPRP3', 'br101_jdepoolcode', 'br101_jdepoolcodedesc',
#        'br112_jdepoolcode', 'br112_jdepoolcodedesc', 'br370_jdepoolcode',
#        'br370_jdepoolcodedesc', 'br371_jdepoolcode', 'br371_jdepoolcodedesc',
#        'br101_jdecost', 'br112_jdecost', 'br370_jdecost', 'br371_jdecost',
#        'partforreference', 'DSC_M_A', 'DSC_M_F', 'DIM', 'CATEGORY_VB',
#        'JDE_UOM', 'DocuNr', 'Material Thickness', 'Bend Radius',
#        'Relief Width', 'Relief Length'],
#       dtype='object')
